# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
#os.getcwd()

# %%
#%%bash
#ls -lt
#find -type d

# %%
#import sys, os, platform, inspect
"""
def get_current_file_path():
    # script filename (usually with path)
    filename = inspect.getfile(inspect.currentframe())
    # script directory
    path = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
    return filename, path


if platform.system() == 'Linux': # Colab setting
    print('Linux')
    from google.colab import drive
    drive.mount('/content/gdrive')
    path = '/content/gdrive/My Drive/Colab Notebooks/GAN'
else:
    _, path = get_current_file_path()    

sys.path.insert(0, path)
os.chdir(path)
"""
# Out:
# "\ndef get_current_file_path():\n    # script filename (usually with path)\n    filename = inspect.getfile(inspect.currentframe())\n    # script directory\n    path = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))\n    return filename, path\n\n\nif platform.system() == 'Linux': # Colab setting\n    print('Linux')\n    from google.colab import drive\n    drive.mount('/content/gdrive')\n    path = '/content/gdrive/My Drive/Colab Notebooks/GAN'\nelse:\n    _, path = get_current_file_path()    \n\nsys.path.insert(0, path)\nos.chdir(path)\n"

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
# import workspace_utils

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torch import utils
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='./processed_celeba_small/celeba'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.CenterCrop(image_size),
        transforms.ToTensor()
    ])
    
    data = datasets.ImageFolder(data_dir, transform = transform)
    
    data_loader = utils.data.DataLoader(dataset = data, batch_size = batch_size, shuffle = True)
    
    # TODO: Implement function and return a dataloader
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 64
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min, max = feature_range
    x = x * (max - min) + min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[1]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9765)
# Max:  tensor(0.9922)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):
    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        
        self.conv_dim = conv_dim

        # complete init function
        self.conv1 = nn.Conv2d(3, conv_dim, 4, stride=2, padding=1, bias=True)
        self.conv2 = nn.Conv2d(conv_dim, 2 * conv_dim, 4, stride=2, padding=1, bias=False)
        self.batchnorm2 = nn.BatchNorm2d(2 * conv_dim)
        self.conv3 = nn.Conv2d(2 * conv_dim, 4 * conv_dim, 4, stride=2, padding=1, bias=False)
        self.batchnorm3 = nn.BatchNorm2d(4 * conv_dim)
        self.fc = nn.Linear(4 * 4 * 4 * conv_dim, 1)
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        x = F.leaky_relu(self.conv1(x))
        x = F.leaky_relu(self.batchnorm2(self.conv2(x)))
        x = F.leaky_relu(self.batchnorm3(self.conv3(x)))
        x = self.fc(x.view(-1, 4 * 4 * 4 * self.conv_dim))
        return x
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    
    layers = []
    transp_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias=False)
    
    layers.append(transp_conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, 4 * 4 * 4 * conv_dim)
        self.deconv1 = nn.ConvTranspose2d(4 * conv_dim, 2 * conv_dim, kernel_size=4, padding=1, stride=2)
        self.batchnorm1 = nn.BatchNorm2d(2 * conv_dim)
        self.deconv2 = nn.ConvTranspose2d(2 * conv_dim, conv_dim, kernel_size=4, padding=1, stride=2)
        self.batchnorm2 = nn.BatchNorm2d(conv_dim)
        self.deconv3 = nn.ConvTranspose2d(conv_dim, 3, kernel_size=4, padding=1, stride=2)
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, 4 * self.conv_dim, 4, 4)
        x = F.relu(self.batchnorm1(self.deconv1(x)))
        x = F.relu(self.batchnorm2(self.deconv2(x)))
        x = torch.tanh(self.deconv3(x)) 
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        
        self.fc = nn.Linear(z_size, conv_dim * 4 * 4 * 4)
        
        self.tconv1 = conv(conv_dim * 4, conv_dim * 2, 4)
        self.tconv2 = conv(conv_dim * 2, conv_dim, 4)
        self.tconv3 = conv(conv_dim, 3, 4, batch_norm = False)
        
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4)
        
        x = F.relu(self.tconv1(x))
        x = F.relu(self.tconv2(x))
        
        x = self.tconv3(x)
        x = torch.tanh(x)
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m, init_gain):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        m.weight.data.normal_(0.0, 0.02)
        if hasattr(m, 'bias') and m.bias is not None:
            m.bias.data.zero_()

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
from torch.nn import init

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size, init_gain):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    weights_init_normal(D, init_gain)
    weights_init_normal(G, init_gain)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
## Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100
init_gain = 0.02

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size, init_gain)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (batchnorm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=4096, bias=True)
#   (tconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (tconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (tconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth = False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    
    labels = torch.ones(batch_size) * 0.9
   
    
    if train_on_gpu:
        labels = labels.cuda()
    
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0005


# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, betas = (0.2, 0.999))
g_optimizer = optim.Adam(G.parameters(), lr, betas = (0.2, 0.999))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        print('training the models on GPU')
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            # real_images = torch.from_numpy(real_images).float()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            if train_on_gpu:
                real_images = real_images.cuda()
            #running real images through D and getting loss
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            #generating latent variable, z
            z = np.random.uniform(-1, 1, size = ( batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            #running fake images through D and getting loss
            fake_images = G(z)
            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            #getting total loss for D
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            z = np.random.uniform(-1, 1, size = ( batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            D_fake = D(fake_images)
            
            g_loss = real_loss(D_fake)
            g_loss.backward()
            g_optimizer.step()
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                print(f'memory allocated {torch.cuda.memory_allocated()/1e9:.2f} Giga-bytes')
                print(f'memory allocated {torch.cuda.memory_cached()/1e9:.2f} Giga-bytes')
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %%
torch.__version__
# Out:
# '1.1.0'

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 15


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# training the models on GPU
# memory allocated 0.03 Giga-bytes
# memory allocated 0.08 Giga-bytes
# Epoch [    1/   15] | d_loss: 1.5016 | g_loss: 1.0304
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.7363 | g_loss: 1.6641
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.9059 | g_loss: 0.7227
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.9111 | g_loss: 0.9619
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 1.0017 | g_loss: 1.2130
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.7297 | g_loss: 1.2968
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 1.1638 | g_loss: 1.0759
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 1.3529 | g_loss: 0.7735
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.8826 | g_loss: 1.4765
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 1.6299 | g_loss: 3.2510
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.7166 | g_loss: 2.1933
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.9541 | g_loss: 1.3955
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.4821 | g_loss: 2.3311
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.6217 | g_loss: 2.8190
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.8731 | g_loss: 1.4600
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.7645 | g_loss: 2.5584
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.9354 | g_loss: 1.4877
# memory allocated 0.03 Giga-bytes
# memory allocated 0.10 Giga-bytes
# Epoch [    1/   15] | d_loss: 0.9086 | g_loss: 1.7723
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.4881 | g_loss: 3.4277
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.6452 | g_loss: 1.8620
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.8206 | g_loss: 1.4305
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.7507 | g_loss: 1.5756
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.7190 | g_loss: 1.9608
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 1.4026 | g_loss: 2.9942
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.7231 | g_loss: 1.6662
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.6992 | g_loss: 1.1673
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.6400 | g_loss: 2.0047
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 1.1975 | g_loss: 1.1717
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.7878 | g_loss: 2.9313
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.8259 | g_loss: 1.9036
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.6207 | g_loss: 1.8662
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.7979 | g_loss: 1.3810
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 1.0901 | g_loss: 1.2856
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.4181 | g_loss: 2.8677
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 0.9631 | g_loss: 2.4761
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    2/   15] | d_loss: 1.3555 | g_loss: 4.0033
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.8045 | g_loss: 3.1064
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.5013 | g_loss: 2.0479
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.7560 | g_loss: 1.2550
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.5772 | g_loss: 3.2794
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.6051 | g_loss: 2.9864
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.7634 | g_loss: 1.8820
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.6145 | g_loss: 1.8164
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.6005 | g_loss: 1.8212
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.6345 | g_loss: 1.9664
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 1.5146 | g_loss: 0.6758
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.6738 | g_loss: 1.8494
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.4635 | g_loss: 2.8964
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.5795 | g_loss: 1.8127
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.6781 | g_loss: 2.5228
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.5599 | g_loss: 2.3741
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 1.0647 | g_loss: 4.0353
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.5490 | g_loss: 2.1135
# memory allocated 0.04 Giga-bytes
# memory allocated 0.11 Giga-bytes
# Epoch [    3/   15] | d_loss: 0.5865 | g_loss: 1.8908
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.7055 | g_loss: 2.3458
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.5993 | g_loss: 2.0932
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6459 | g_loss: 1.9226
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6598 | g_loss: 1.7936
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6791 | g_loss: 1.8617
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6996 | g_loss: 1.8869
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6097 | g_loss: 2.6206
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 1.1869 | g_loss: 4.2492
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6271 | g_loss: 2.1277
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6689 | g_loss: 2.1997
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.4803 | g_loss: 2.3249
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6874 | g_loss: 1.8770
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 2.2911 | g_loss: 0.9332
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.8592 | g_loss: 1.4983
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.7052 | g_loss: 1.6548
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.6388 | g_loss: 1.7622
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.9142 | g_loss: 1.5106
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    4/   15] | d_loss: 0.4924 | g_loss: 3.1410
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5802 | g_loss: 2.2718
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5775 | g_loss: 2.3278
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 1.1918 | g_loss: 4.1144
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 1.1622 | g_loss: 4.0345
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.7126 | g_loss: 3.2619
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5722 | g_loss: 2.2894
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5786 | g_loss: 2.4912
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5534 | g_loss: 2.6703
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5982 | g_loss: 2.4186
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.4999 | g_loss: 2.5352
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.4735 | g_loss: 2.8316
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.4743 | g_loss: 2.7833
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5534 | g_loss: 1.6804
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.8638 | g_loss: 2.7113
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.6028 | g_loss: 2.3689
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5250 | g_loss: 1.9846
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.7329 | g_loss: 2.6060
# memory allocated 0.05 Giga-bytes
# memory allocated 0.12 Giga-bytes
# Epoch [    5/   15] | d_loss: 0.5183 | g_loss: 2.2303
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.6218 | g_loss: 2.6584
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5998 | g_loss: 2.3164
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5957 | g_loss: 2.5528
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 1.1678 | g_loss: 1.0101
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5269 | g_loss: 2.3966
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.4446 | g_loss: 2.7938
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.7963 | g_loss: 2.9984
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.4789 | g_loss: 2.4233
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5165 | g_loss: 1.8839
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5526 | g_loss: 2.7621
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5979 | g_loss: 2.2928
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5486 | g_loss: 1.7950
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5416 | g_loss: 2.4092
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.6428 | g_loss: 1.8790
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.7024 | g_loss: 1.8686
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.5537 | g_loss: 2.2661
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 0.7103 | g_loss: 1.5704
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    6/   15] | d_loss: 1.0107 | g_loss: 3.9785
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.7236 | g_loss: 4.0709
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.8342 | g_loss: 1.9307
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.8546 | g_loss: 3.1285
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.7615 | g_loss: 1.0071
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.5220 | g_loss: 2.7019
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.6041 | g_loss: 1.9290
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 2.1671 | g_loss: 1.4285
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.5267 | g_loss: 2.1532
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 1.1559 | g_loss: 1.3886
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.9162 | g_loss: 1.4504
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.4971 | g_loss: 2.4367
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.5657 | g_loss: 2.0223
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 1.0288 | g_loss: 5.0819
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.6245 | g_loss: 1.9999
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.4891 | g_loss: 2.5887
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.5049 | g_loss: 2.7918
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.4840 | g_loss: 2.3991
# memory allocated 0.06 Giga-bytes
# memory allocated 0.13 Giga-bytes
# Epoch [    7/   15] | d_loss: 0.9049 | g_loss: 2.8940
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.6021 | g_loss: 2.1746
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.4047 | g_loss: 3.7548
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.6390 | g_loss: 1.9165
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.4624 | g_loss: 2.8825
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 1.6574 | g_loss: 5.9210
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.4854 | g_loss: 2.6971
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.5919 | g_loss: 2.0973
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.4872 | g_loss: 2.3717
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.4926 | g_loss: 1.4570
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0.5770 | g_loss: 1.9832
# memory allocated 0.07 Giga-bytes
# memory allocated 0.14 Giga-bytes
# Epoch [    8/   15] | d_loss: 0
# memory allocated 0.09 Giga-bytes
# memory allocated 0.16 Giga-bytes
# Epoch [   12/   15] | d_loss: 0.4734 | g_loss: 2.7503
# memory allocated 0.09 Giga-bytes
# memory allocated 0.16 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4448 | g_loss: 3.5550
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4868 | g_loss: 2.8805
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4217 | g_loss: 3.1116
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.6618 | g_loss: 4.5957
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4622 | g_loss: 3.5311
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.5265 | g_loss: 2.0408
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.5165 | g_loss: 3.8320
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4744 | g_loss: 3.3708
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4425 | g_loss: 3.6136
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4040 | g_loss: 3.8625
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4925 | g_loss: 3.1832
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4710 | g_loss: 3.1913
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4042 | g_loss: 2.9022
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4625 | g_loss: 4.2492
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4296 | g_loss: 3.0386
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.6200 | g_loss: 2.2406
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.4269 | g_loss: 2.9598
# memory allocated 0.09 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   13/   15] | d_loss: 0.5078 | g_loss: 3.1732
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.5143 | g_loss: 4.0229
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4502 | g_loss: 3.3812
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4729 | g_loss: 3.8084
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.5404 | g_loss: 3.8239
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.5439 | g_loss: 3.3701
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4771 | g_loss: 4.2330
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.5476 | g_loss: 3.7065
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4253 | g_loss: 3.0591
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.7327 | g_loss: 2.6919
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4259 | g_loss: 4.1561
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4622 | g_loss: 2.4817
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 1.0933 | g_loss: 0.5730
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4833 | g_loss: 2.8806
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4253 | g_loss: 3.4527
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4666 | g_loss: 2.7713
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4331 | g_loss: 2.8317
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.4180 | g_loss: 3.4385
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   14/   15] | d_loss: 0.6573 | g_loss: 3.0398
# memory allocated 0.10 Giga-bytes
# memory allocated 0.17 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.4357 | g_loss: 3.1042
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.4491 | g_loss: 3.3624
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.3923 | g_loss: 3.4559
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.4440 | g_loss: 2.5368
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.5125 | g_loss: 1.9389
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.5985 | g_loss: 2.0745
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.4390 | g_loss: 2.9780
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.5327 | g_loss: 2.8468
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.4259 | g_loss: 2.7395
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.5755 | g_loss: 2.8664
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.5965 | g_loss: 3.6594
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 1.3813 | g_loss: 0.8093
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.4894 | g_loss: 3.0561
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.7970 | g_loss: 2.0977
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 1.0269 | g_loss: 4.9912
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.7516 | g_loss: 4.4326
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.3957 | g_loss: 3.6121
# memory allocated 0.10 Giga-bytes
# memory allocated 0.18 Giga-bytes
# Epoch [   15/   15] | d_loss: 0.8170 | g_loss: 5.3538

# %%
losses
# Out:
# [(1.501615047454834, 1.0304011106491089),
#  (0.7363216876983643, 1.664123296737671),
#  (0.9058661460876465, 0.7226841449737549),
#  (0.9110774993896484, 0.9619050025939941),
#  (1.0016878843307495, 1.2129746675491333),
#  (0.7297087907791138, 1.2968271970748901),
#  (1.1637978553771973, 1.07594895362854),
#  (1.3528903722763062, 0.7734668850898743),
#  (0.8825575113296509, 1.476511001586914),
#  (1.6298794746398926, 3.250974178314209),
#  (0.7165864109992981, 2.1932942867279053),
#  (0.9541223049163818, 1.3954505920410156),
#  (0.4820507764816284, 2.331141710281372),
#  (0.6217172145843506, 2.8189563751220703),
#  (0.873131513595581, 1.4600274562835693),
#  (0.6152305006980896, 2.447678565979004),
#  (0.512302041053772, 2.595606803894043),
#  (0.4972435235977173, 2.4587907791137695),
#  (0.44786494970321655, 3.3788156509399414),
#  (0.4341629445552826, 3.0706095695495605),
#  (1.0562459230422974, 4.834002494812012),
#  (0.47342777252197266, 2.750335693359375),
#  (0.444764107465744, 3.5549960136413574),
#  (0.48677101731300354, 2.8804965019226074),
#  (0.4217105507850647, 3.111607074737549),
#  (0.6617727279663086, 4.595731735229492),
#  (0.4622032344341278, 3.531130790710449),
#  (0.5264787673950195, 2.0407581329345703),
#  (0.516483724117279, 3.83204984664917),
#  (0.4744158983230591, 3.3707613945007324),
#  (0.44248390197753906, 3.6135525703430176),
#  (0.40396595001220703, 3.862457752227783),
#  (0.49245598912239075, 3.183225154876709),
#  (0.4710184931755066, 3.191303253173828),
#  (0.40420228242874146, 2.9021780490875244),
#  (0.46250784397125244, 4.249242305755615),
#  (0.42964252829551697, 3.0385899543762207),
#  (0.6199926137924194, 2.2406136989593506),
#  (0.4269007444381714, 2.9597954750061035),
#  (0.507757306098938, 3.1731643676757812),
#  (0.5142838954925537, 4.022928237915039),
#  (0.4501630961894989, 3.3811869621276855),
#  (0.4728549122810364, 3.8083903789520264),
#  (0.5404382348060608, 3.8238775730133057),
#  (0.5439164042472839, 3.3701140880584717),
#  (0.4771457016468048, 4.232958793640137),
#  (0.547588586807251, 3.7065329551696777),
#  (0.42534664273262024, 3.059072732925415),
#  (0.7326767444610596, 2.6918601989746094),
#  (0.42588549852371216, 4.1560869216918945),
#  (0.4622098505496979, 2.4816908836364746),
#  (1.0932643413543701, 0.5730332732200623),
#  (0.48329034447669983, 2.8805580139160156),
#  (0.4253167510032654, 3.4526875019073486),
#  (0.4666188955307007, 2.7712621688842773),
#  (0.4331018924713135, 2.831660747528076),
#  (0.4180390536785126, 3.4384872913360596),
#  (0.65730881690979, 3.0398244857788086),
#  (0.4357489347457886, 3.10424542427063),
#  (0.4491121768951416, 3.3624353408813477),
#  (0.392283171415329, 3.4559478759765625),
#  (0.44397634267807007, 2.536844491958618),
#  (0.5124889612197876, 1.9388798475265503),
#  (0.5985117554664612, 2.0744729042053223),
#  (0.4389503300189972, 2.978041172027588),
#  (0.5327262282371521, 2.8468151092529297),
#  (0.4259403645992279, 2.7395195960998535),
#  (0.5755013823509216, 2.866446018218994),
#  (0.596508264541626, 3.659353017807007),
#  (1.381300449371338, 0.809290885925293),
#  (0.4894229769706726, 3.0561108589172363),
#  (0.7970361709594727, 2.0976762771606445),
#  (1.0269410610198975, 4.991229057312012),
#  (0.7516112327575684, 4.432583332061768),
#  (0.39568307995796204, 3.612104892730713),
#  (0.8169600963592529, 5.353832244873047)]

# %%
print(torch.cuda.memory_cached)
# Out:
# <function memory_cached at 0x7f360b6b4d90>

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
#
# Add faces of different colour. Model could include dropout and perhaps a residual component in the convolutional networks. Train for more epochs (although not too many).

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
